# %%
import pywikibot
from util import *
from tqdm import tqdm
import random

# %%
# Store things as pairs: (stack, dict) where stack is
# the stack associated to a dfs, and dict is
# a dictionary sending each neighbor of a previous element of stack
# to its parent that showed up earliest in the list.
# A possible future update is to also include the distance
# from the origin in the dict, so the image of the dict
# would be an ordered pair (parent, distance). 
# Another potential improvement is to expand the depth-first search
# on the side whose dictionary is smaller, rather than just alternating

# %%
# Updates a pair and returns 1 if it finds a path,
# 0 if it does not find a path but updates successfully,
# and -1 if there is nowhere to expand.
# By default, the first pair is the one updated.
# careful_bookkeeping means that the pairs will be updated correctly
# even if a path is found.
def expand_one_node(pair1, pair2, expand_first = True, pair1_to_pair2 = True, careful_bookkeeping=True):
    if not expand_first:
        return expand_one_node(pair2, pair1, pair1_to_pair2 = not pair1_to_pair2, careful_bookkeeping = careful_bookkeeping)

    try:
        item_to_expand, path = pair1[0].pop()
        
        if pair1_to_pair2:
            potential_expansions = item_to_expand.get_successors()
        else:
            potential_expansions = item_to_expand.get_predecessors()
        # good potential expansions are those that have not been seen before
        # in either dictionary.  It is not completely obvious, but not hard to show
        # that if we get stuck by avoiding words in this way, then there is no path
        # from start to end.
        good_potential_expansions = []
        for item in potential_expansions:            
            if valid_page(item.title()):
                if not careful_bookkeeping:
                    if item in pair2[1].keys():
                        # if we have seen this neighbor when extending the other pair
                        pair1[0].append((item, path + [item]))
                        return 1
                    elif item not in pair1[1].keys():
                        good_potential_expansions.append((item, path + [item]))
                        pair1[1][item] = item_to_expand
                else:
                    pass #TODO

        # The dictionary has already been updated during the loop
        # so we only have to update the stack now
        pair1[0].extend(good_potential_expansions)
        
    except:
        # If the stack is empty
        return -1

# %%
# use_first means that the path works by
# travelling down the stack of pair1
# followed by going backwards down pair2;
# not use_first means the opposite.
def generate_path(pair1,pair2,use_first):
    if use_first:
        endpoint, path = pair1[0].pop()
        dict = pair2[1]
        while endpoint != None:
            endpoint = dict[endpoint]
            path.append(endpoint)
        path = path[:-1]
    else:
        # This is equivalent to the following:
        # path = generate_path(pair2,pair1,not use_first)
        # path.reverse()
        endpoint, path = pair2[0].pop()
        dict = pair1[1]
        while endpoint != None:
            endpoint = dict[endpoint]
            path.append(endpoint)
        path = path[:-1]
        path.reverse()
    return path

# %%
def set_use_first(previous_use_first, pair1, pair2):
    return not previous_use_first

# %%
# If start == end then this returns
# a cycle in the graph, not the empty path.
#
# if return_expansions == False, the output is the path as a list
# if return_expansions == True, the output is a tuple (path, num_expansions)
# where num_epansions is the number of nodes expanded.
# In either case, the number of nodes expanded is counted;
# return_expansions only affects whether it is returned
def bidirectional_DFS_graph(start, end, return_expansions=False):
    stack1 = [(start,[start])]
    stack2 = [(end,[end])]
    dict1 = {start:None}
    dict2 = {end:None}
    num_expansions = 0

    use_first = True
    while True:            
        result = expand_one_node((stack1, dict1), (stack2, dict2), expand_first = use_first, careful_bookkeeping = False)
        num_expansions += 1
        if result == 1:
            path = generate_path((stack1,dict1),(stack2,dict2),use_first)
            if return_expansions:
                return (path,num_expansions)
            else:
                return path
        elif result == -1:
            if return_expansions:
                return (False,num_expansions)
            else:
                return (False,num_expansions)
        
        use_first = set_use_first(use_first, (stack1, dict1), (stack2, dict2))

# %%
class PageNode:
    def __init__(self,page):
        self.page = page
        
    def __str__(self):
        return str(self.page)
    
    def __repr__(self):
        return repr(self.page)
    
    def __eq__(self, other):
        try:
            return self.page == other.page
        except:
            # If other does not have a page attribute
            # (Main intended use case: If other == None)
            return False
    
    def __hash__(self):
        return hash(self.page)
    
    def title(self):
        return self.page.title()
        
    def get_successors(self):
        pages = [PageNode(page) for page in list(self.page.linkedPages())]
        random.shuffle(pages)
        return pages
    
    def get_predecessors(self):
        pages = [PageNode(page) for page in list(self.page.backlinks())]
        random.shuffle(pages)
        return pages

# %%
site = pywikibot.Site("en", "wikipedia")

# %%
def PageNode_from_title(title):
    return PageNode(pywikibot.Page(site,title))

# %%
def bidirectional_DFS(start, end):
    return bidirectional_DFS_graph(PageNode_from_title(start),PageNode_from_title(end), return_expansions = True)

# %%
examples = get_samples(100)

# %%
def run_search(search_method, search_tuples, **kwargs):
    results = {}
    for start, goal in tqdm(search_tuples):
        results[(start, goal)] = search_method(start, goal, **kwargs)
    return results

# %%
output = run_search(bidirectional_DFS,examples)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 100/100 [25:50<00:00, 18.26s/it]

# %%
output
# Out:
# {('Transhumanism',
#   'Saturn'): ([Page('Transhumanism'),
#    Page('Potentially hazardous object'),
#    Page('Saturn')], 2),
#  ('Vacuum',
#   'Jim Henson'): ([Page('Vacuum'),
#    Page('Crookes tube'),
#    Page('Nobel Prize in Physics'),
#    Page('Lawrence Bragg'),
#    Page('Fullerian Professor of Chemistry'),
#    Page('John Meurig Thomas'),
#    Page('American Philosophical Society'),
#    Page('Patriot (American Revolution)'),
#    Page('Saul Matthews'),
#    Page('Charles Cornwallis, 1st Marquess Cornwallis'),
#    Page('United States'),
#    Page('Orson Welles'),
#    Page('Jim Henson')], 21),
#  ('Earth', 'Chimpanzee'): ([Page('Earth'), Page('Human'), Page('Chimpanzee')],
#   2),
#  ('Renaissance',
#   'Dancing with the Stars'): ([Page('Renaissance'),
#    Page('Augustinians'),
#    Page('Oblate Sisters of the Virgin Mary of Fatima'),
#    Page('Spiritual Exercises of Ignatius of Loyola'),
#    Page('Santa Maria de Montserrat Abbey'),
#    Page('Province of Barcelona'),
#    Page('La Granada'),
#    Page('Mayor'),
#    Page('Acting President of the United States'),
#    Page('Governor of Nebraska'),
#    Page('Dwight W. Burney'),
#    Page('Rick Sheehy'),
#    Page('National Lieutenant Governors Association'),
#    Page('Running mate'),
#    Page('Bangladesh'),
#    Page('Albania'),
#    Page('Dancing with the Stars')], 31),
#  ('dna',
#   'War of 1812'): ([Page('Dna'),
#    Page('DNA'),
#    Page('Restriction enzyme'),
#    Page('Streptomyces caespitosus'),
#    Page('Taxonomy (biology)'),
#    Page('Family (biology)'),
#    Page('Botanical nomenclature'),
#    Page('Cultivar group'),
#    Page('International Society for Horticultural Science'),
#    Page('Education'),
#    Page('First Lady of the United States'),
#    Page('War of 1812')], 19),
#  ('Kidney',
#   'Wesley Snipes'): ([Page('Kidney'),
#    Page('Urethral sphincters'),
#    Page('Vaginoplasty'),
#    Page('Transsexual'),
#    Page('Drag queen'),
#    Page('Wesley Snipes')], 7),
#  ('Brown Bear',
#   'World Series'): ([Page('Brown Bear'),
#    Page('Brown bear'),
#    Page('Eurasia'),
#    Page('San Francisco Bay Area'),
#    Page('World Series')], 5),
#  ('Copyright infringement',
#   'Bipolar junction transistor'): ([Page('Copyright infringement'),
#    Page('Aaron Swartz'),
#    Page('OpenCores'),
#    Page('Hardware acceleration'),
#    Page('Netlist'),
#    Page('Bipolar junction transistor')], 6),
#  ('Saxophone',
#   'Lactose intolerance'): ([Page('Saxophone'),
#    Page('MusicBrainz'),
#    Page('AmpliFIND'),
#    Page('Dual license'),
#    Page('Multi-licensing'),
#    Page('Attribution (copyright)'),
#    Page('Respect'),
#    Page('Lakshmi'),
#    Page('Brahmin'),
#    Page('Atri'),
#    Page('Aryaman'),
#    Page('Aditi'),
#    Page('Theosophy (Boehmian)'),
#    Page('Divine simplicity'),
#    Page('Godhead in Christianity'),
#    Page('King James Version'),
#    Page('Robert Ward (scholar)'),
#    Page('Prebendary'),
#    Page('Anglicanism'),
#    Page('Liturgical Movement'),
#    Page('Requiem'),
#    Page('A German Requiem (Brahms)'),
#    Page('Düsseldorf'),
#    Page('Armenia in the Eurovision Song Contest'),
#    Page('Stockholm'),
#    Page('Finland'),
#    Page('Lactose intolerance')], 57),
#  ('World Health Organization',
#   'Life expectancy'): ([Page('World Health Organization'),
#    Page('Developing country'),
#    Page('Life expectancy')], 2),
#  ('Sherlock Holmes',
#   'Knife'): ([Page('Sherlock Holmes'),
#    Page('P. G. Wodehouse'),
#    Page('The White Feather'),
#    Page('Send to Coventry'),
#    Page('Peeping Tom'),
#    Page('Lady Godiva'),
#    Page('Latinisation of names'),
#    Page('Proper noun'),
#    Page('Human'),
#    Page('Knife')], 15),
#  ('River',
#   'Blood pressure'): ([Page('River'),
#    Page('Pressure'),
#    Page('Blood pressure')], 2),
#  ('Gin',
#   'Mountain'): ([Page('Gin'),
#    Page('Distillation'),
#    Page('Acid-base extraction'),
#    Page('Sodium hydroxide'),
#    Page('Phosphorus mononitride'),
#    Page('Phosphorus pentafluoride'),
#    Page('Chlorine pentafluoride'),
#    Page('Chlorine monofluoride'),
#    Page('Coulomb'),
#    Page('Siemens (unit)'),
#    Page('General Conference on Weights and Measures'),
#    Page('Albania'),
#    Page('Mountain')], 25),
#  ('Francis Ford Coppola',
#   'RNA'): ([Page('Francis Ford Coppola'),
#    Page('Titanic (1997 film)'),
#    Page('Memorial to the Engine Room Heroes of the Titanic'),
#    Page("St George's Church, Everton"),
#    Page('Grade I listed churches in Merseyside'),
#    Page('William Huskisson'),
#    Page('Margaret Beckett'),
#    Page('Charles Clarke'),
#    Page('Herbert Gladstone, 1st Viscount Gladstone'),
#    Page('Walter Hely-Hutchinson'),
#    Page('Anglo-Irish'),
#    Page('Anglo-Irish people'),
#    Page('Irish literature'),
#    Page('Uncle Silas'),
#    Page('Occult'),
#    Page('Israel Regardie'),
#    Page('Christian Science'),
#    Page('Sulfonamide (medicine)'),
#    Page('RNA')], 35),
#  ('Association football',
#   'lacrosse'): ([Page('Association football'), Page('Lacrosse')], 1),
#  ('Muscle car',
#   'Nuclear Power'): ([Page('Muscle car'),
#    Page('Electric vehicle'),
#    Page('Nuclear Power')],
#   2),
#  ('Statistics', 'angelina jolie'): (False, 4),
#  ('Caroline Kennedy',
#   'Joan Baez'): ([Page('Caroline Kennedy'),
#    Page('Bouffant'),
#    Page('Joan Baez')], 2),
#  ('Written language',
#   'speech'): ([Page('Written language'), Page('Writing'), Page('Speech')], 2),
#  ('Waterboarding',
#   'Ecology'): ([Page('Waterboarding'),
#    Page('Heart attack'),
#    Page('Synonym'),
#    Page('Meta'),
#    Page('Aristotle'),
#    Page('Ecology')],
#   7),
#  ('Dance music',
#   'Pathology'): ([Page('Dance music'),
#    Page('Cha-cha-cha (dance)'),
#    Page('Glossary of partner dance terms'),
#    Page('Promenade position'),
#    Page('Lindy Basic'),
#    Page('Swingout'),
#    Page('Modern Jive'),
#    Page('Switzerland'),
#    Page('Regulation'),
#    Page('Homeostasis'),
#    Page('Pathology')], 19),
#  ('Computer science',
#   'Death of Adolf Hitler'): ([Page('Computer science'),
#    Page('World War II'),
#    Page('Death of Adolf Hitler')], 2),
#  ('Bavaria',
#   'Canadians'): ([Page('Bavaria'),
#    Page('Kingdom of Prussia'),
#    Page('Waldemar Pabst'),
#    Page('Belgium'),
#    Page('Quebec'),
#    Page('Canadians')], 7),
#  ('Jellyfish',
#   'Bilirubin'): ([Page('Jellyfish'), Page('Itch'), Page('Bilirubin')], 2),
#  ('War of 1812',
#   'Southern Europe'): ([Page('War of 1812'),
#    Page('United States'),
#    Page('Southern Europe')],
#   2),
#  ('Al-Qaeda',
#   'Radio'): ([Page('Al-Qaeda'),
#    Page('Psychological warfare'),
#    Page('Radio')], 2),
#  ('Cologne',
#   'Battleship'): ([Page('Cologne'),
#    Page('Asian people'),
#    Page('Activism'),
#    Page('Victor Gold (journalist)'),
#    Page('Sexual intercourse'),
#    Page('African wild dog'),
#    Page('Tshivenda language'),
#    Page('Venda language'),
#    Page('Mbule language'),
#    Page('Mefele language'),
#    Page('Cibak language'),
#    Page('Polci language'),
#    Page('Voiceless postalveolar fricative'),
#    Page('Mopan language'),
#    Page('Languages of Guatemala'),
#    Page('Languages of Saint Pierre and Miquelon'),
#    Page('Saint Pierre and Miquelon'),
#    Page('Morocco'),
#    Page('Index of Morocco-related articles'),
#    Page("Association Marocaine des Droits de l'Homme"),
#    Page('Association Marocaine des Droits Humains'),
#    Page('Temara'),
#    Page('Azilal Province'),
#    Page('Ait Ouqabli'),
#    Page('Western European Summer Time'),
#    Page('Military history of the United Kingdom during World War II'),
#    Page('Battleship')], 49),
#  ('Megalodon',
#   'Coaxial cable'): ([Page('Megalodon'),
#    Page('Asia'),
#    Page('Carl Blegen'),
#    Page('Oslo'),
#    Page('Løten'),
#    Page('Løten Station'),
#    Page('Røros Station'),
#    Page('Bane NOR'),
#    Page('Norwegian Communications Authority'),
#    Page('Coaxial cable')], 12),
#  ('Ralph Waldo Emerson',
#   'Marine biology'): ([Page('Ralph Waldo Emerson'),
#    Page('Brothers Grimm'),
#    Page('Cinderella (1950 film)'),
#    Page('Mickey Mousing'),
#    Page('Model animation'),
#    Page('20 Million Miles to Earth'),
#    Page('Marine biology')], 16),
#  ('Documentary film',
#   'Bacteria'): ([Page('Documentary film'),
#    Page('Romania'),
#    Page('Bacteria')], 2),
#  ('Auto racing',
#   'Ethernet'): ([Page('Auto racing'),
#    Page('Short course off road racing'),
#    Page('Sal Fish'),
#    Page('Los Angeles'),
#    Page('ARPANET'),
#    Page('Ethernet')], 7),
#  ('Michelangelo',
#   'Horror Fiction'): ([Page('Michelangelo'),
#    Page('Francis I of France'),
#    Page('Dieppe, Seine-Maritime'),
#    Page('Dieppe'),
#    Page('Johnny Depp'),
#    Page('I Put a Spell on You'),
#    Page('Them (band)'),
#    Page('Jackie McAuley'),
#    Page('Clodagh Rodgers'),
#    Page('The New Seekers'),
#    Page('Circles (The New Seekers album)'),
#    Page('Todd Rundgren'),
#    Page('Iolanthe'),
#    Page('Valerie Masterson'),
#    Page('Chérubin'),
#    Page('Méditation (Thaïs)'),
#    Page('Jazz Calendar'),
#    Page("Monday's Child"),
#    Page('Alethea Kontis'),
#    Page('Horror Fiction')], 32),
#  ('Pony Express',
#   'Jacob'): ([Page('Pony Express'),
#    Page('Into the West (miniseries)'),
#    Page('Lance Henriksen'),
#    Page('Caminhos do Coração'),
#    Page('Os Dez Mandamentos'),
#    Page('Miriam'),
#    Page('Jacob')], 12),
#  ('Prussia',
#   'nitrogen'): ([Page('Prussia'),
#    Page('Gott mit uns'),
#    Page('Deutschlandlied'),
#    Page('Neman'),
#    Page('Nitrogen')], 5),
#  ('Americans',
#   'Rhodesia'): ([Page('Americans'), Page('Africa'), Page('Rhodesia')], 2),
#  ('Nobel Prize in Physiology or Medicine',
#   'World Trade Organization'): ([Page('Nobel Prize in Physiology or Medicine'),
#    Page('Germany'),
#    Page('World Trade Organization')],
#   2),
#  ('Engine',
#   'Multi-sport event'): ([Page('Engine'),
#    Page('Trebuchet'),
#    Page('Chinese siege weapons'),
#    Page('Wu (state)'),
#    Page('Wa (Japan)'),
#    Page('Unicode'),
#    Page('Unicode character property'),
#    Page('Gaelic type'),
#    Page('Highland games'),
#    Page('Multi-sport event')], 15),
#  ('Church of England',
#   'African-American music'): ([Page('Church of England'),
#    Page('Anglican Consultative Council'),
#    Page('Canada'),
#    Page('Black Canadians'),
#    Page('African Hebrew Israelites of Jerusalem'),
#    Page('African-American music')], 7),
#  ('Sheep',
#   'James II of England'): ([Page('Sheep'),
#    Page('Nursery rhyme'),
#    Page('James II of England')], 2),
#  ('William Shakespeare',
#   'Nevada'): ([Page('William Shakespeare'),
#    Page('Roméo et Juliette (Berlioz)'),
#    Page('Mémoires (Berlioz)'),
#    Page('Random House'),
#    Page('New York (state)'),
#    Page('Nevada')], 7),
#  ('Ornithology',
#   'Google Chrome'): ([Page('Ornithology'),
#    Page('Christopher Merrett'),
#    Page('Christopher Merret'),
#    Page('Old Style and New Style dates'),
#    Page('The Hague'),
#    Page('Sense8'),
#    Page('YouTube'),
#    Page('Google Chrome')], 11),
#  ('Radiohead',
#   'Armageddon'): ([Page('Radiohead'),
#    Page('Sampling (music)'),
#    Page('Keyboard (magazine)'),
#    Page('PlayStation Official Magazine - UK'),
#    Page('PlayStation Official Magazine – UK'),
#    Page('PlayStation 3 system software'),
#    Page('Software release life cycle'),
#    Page('Retail software'),
#    Page('Microsoft Office'),
#    Page('Usenet newsgroup'),
#    Page('World Wide Web'),
#    Page('Web Accessibility Initiative'),
#    Page('C-HTML'),
#    Page('I-mode'),
#    Page('London Underground'),
#    Page('London Underground 1956 Stock'),
#    Page('Associated Electrical Industries'),
#    Page('Thomson Marconi Sonar'),
#    Page('Telespazio'),
#    Page('Spaceflight'),
#    Page('Ariel (moon)'),
#    Page('Cryovolcano'),
#    Page('Decade Volcanoes'),
#    Page('Volcanic winter'),
#    Page('Armageddon')], 41),
#  ('Ghetto',
#   'Dream'): ([Page('Ghetto'),
#    Page('Detroit'),
#    Page('Jeff Mills'),
#    Page('The Marshall Mathers LP 2'),
#    Page('Polina (singer)'),
#    Page('Party All Night (Sleep All Day)'),
#    Page('Rum and Raybans'),
#    Page('Swagger Jagger'),
#    Page('The Monsters and the Strangerz'),
#    Page("Amazin' (Trina album)"),
#    Page('Trina discography'),
#    Page('Get Money, Stay True'),
#    Page('Paul Wall discography'),
#    Page('Helpless Romantic'),
#    Page('Emile Ghantous'),
#    Page('Whatta Man (I.O.I song)'),
#    Page('Chrysalis (EP)'),
#    Page('Melanie Fontana'),
#    Page('Dance in the Rain (Koda Kumi song)'),
#    Page('W Face: Inside/Outside'),
#    Page('Viktoria Hansen'),
#    Page('DaVinChe'),
#    Page('Something About Your Smile (song)'),
#    Page('Bright Lights (Tinchy Stryder song)'),
#    Page('Pixie Lott discography'),
#    Page('Brighter Day (song)'),
#    Page('Fighter (Namie Amuro song)'),
#    Page('Emyli'),
#    Page('Dream')], 52),
#  ('Adolf Hitler',
#   'Vermont'): ([Page('Adolf Hitler'),
#    Page('Mark Zuckerberg'),
#    Page('Vermont')], 2),
#  ('Parthenon',
#   'Mathematics'): ([Page('Parthenon'),
#    Page('Golden ratio'),
#    Page('Mathematics')], 2),
#  ('Potato',
#   "Alzheimer's disease"): ([Page('Potato'),
#    Page('United States'),
#    Page("Alzheimer's disease")], 2),
#  ('Comedian',
#   'Mark Wahlberg'): ([Page('Comedian'),
#    Page('2015 MTV Movie Awards'),
#    Page('Mark Wahlberg')], 2),
#  ('Bruce Lee',
#   'Jules Verne'): ([Page('Bruce Lee'),
#    Page('Kim Tai Chung'),
#    Page('Kim Tai-chung'),
#    Page('Jackie Chan'),
#    Page('Jules Verne')], 5),
#  ('Dictionary',
#   'Graphical User Interface'): ([Page('Dictionary'),
#    Page('French language'),
#    Page('French language in Vietnam'),
#    Page('Pidgin language'),
#    Page('Pidgin'),
#    Page('Prestige (sociolinguistics)'),
#    Page('Language planning'),
#    Page('Linguistic prescription'),
#    Page('Middle Kingdom of Egypt'),
#    Page('Thirteenth Dynasty of Egypt'),
#    Page('Iufni'),
#    Page('Sekhemre-Heruhirmaat Intef'),
#    Page('Ra'),
#    Page('Winged sun'),
#    Page('Studies in the Scriptures'),
#    Page('Dawn Bible Students Association'),
#    Page('Holy Spirit in Christianity'),
#    Page('Synergism (theology)'),
#    Page('Formula of Concord'),
#    Page('Johannes Agricola'),
#    Page('Abrogation of Old Covenant laws'),
#    Page('Law of Christ'),
#    Page('Outline of Bible-related topics'),
#    Page('Book of Nahum'),
#    Page('Jerusalem'),
#    Page('Thailand'),
#    Page('Index of Thailand-related articles'),
#    Page('Index of Thailand-related articles 0 to J'),
#    Page('Apichatpong Weerasethakul'),
#    Page('Peter Sellars'),
#    Page("L'Amour de loin"),
#    Page('Susanna Mälkki'),
#    Page('2017 in Finnish music'),
#    Page('2016 in Finnish music'),
#    Page('2016 in European music'),
#    Page('2015 in European music'),
#    Page('2015 in Latin music'),
#    Page('Soy Libre (song)'),
#    Page('A Forgotten Spot'),
#    Page('The Hamilton Mixtape'),
#    Page('MTV Video Music Award for Best Video with a Social Message'),
#    Page('1998 MTV Video Music Awards'),
#    Page("It's All About the Benjamins"),
#    Page('Victory (Puff Daddy song)'),
#    Page('Stevie J'),
#    Page('Stevie J production discography'),
#    Page('Tamia (album)'),
#    Page("Q's Jook Joint"),
#    Page('Tone Loc'),
#    Page('ToneLoc'),
#    Page('War dialing'),
#    Page('Sandstorm Enterprises'),
#    Page('FTP Software'),
#    Page('Comparison of FTP server software packages'),
#    Page('Graphical User Interface')], 62),
#  ('Moors',
#   'Personal computer'): ([Page('Moors'),
#    Page('Italy'),
#    Page('Personal computer')], 2),
#  ('Humid subtropical climate',
#   'Mammal'): ([Page('Humid subtropical climate'),
#    Page('Bulgaria'),
#    Page('Mammal')], 2),
#  ('Yellowstone National Park',
#   'Credit card'): ([Page('Yellowstone National Park'),
#    Page('Black Coulee National Wildlife Refuge'),
#    Page('Canada–United States border'),
#    Page('Mass surveillance in the United States'),
#    Page('Credit card')], 5),
#  ('Jim Carrey',
#   'Latitude'): ([Page('Jim Carrey'),
#    Page('Arnold Schwarzenegger'),
#    Page('New York (state)'),
#    Page('Latitude')], 3),
#  ('Natural Environment',
#   'Sociology'): ([Page('Natural Environment'),
#    Page('Natural environment'),
#    Page('Sociology')], 2),
#  ('Profession',
#   'List of U.S. states and territories by area'): ([Page('Profession'),
#    Page('Mechanical engineering'),
#    Page('Aluminum'),
#    Page('Aluminium'),
#    Page('Cation'),
#    Page('Phrase'),
#    Page('Exocentric'),
#    Page('Endocentric and exocentric'),
#    Page('Endocentric environment'),
#    Page('Rear projection screen'),
#    Page('Video projector'),
#    Page('Computer-generated holography'),
#    Page('CiteSeerX'),
#    Page('Kurt Bollacker'),
#    Page('Applied Minds'),
#    Page('Burbank, California'),
#    Page('San Joaquin Valley'),
#    Page('Mississippi'),
#    Page('List of U.S. states and territories by area')], 33),
#  ('Nevada',
#   'Web search engine'): ([Page('Nevada'),
#    Page('United States'),
#    Page('Web search engine')], 2),
#  ('World War II',
#   'Mathematics'): ([Page('World War II'),
#    Page('Operations research'),
#    Page('Mathematics')], 2),
#  ('Brain tumor',
#   'Pistol'): ([Page('Brain tumor'),
#    Page('Boron neutron capture therapy'),
#    Page('Neutron capture therapy of cancer'),
#    Page('Aircraft Nuclear Propulsion'),
#    Page('Middletown, Connecticut'),
#    Page('Pistol')], 7),
#  ('The Cosby Show',
#   'Eurozone'): ([Page('The Cosby Show'),
#    Page('Parks and Recreation (season 5)'),
#    Page("Andy and April's Fancy Party"),
#    Page('Nell (film)'),
#    Page('Barfi!'),
#    Page('Raajneeti'),
#    Page('Ajay Devgn'),
#    Page('Emraan Hashmi'),
#    Page('Bookmaker'),
#    Page('European Economic Area'),
#    Page('Eurozone')], 17),
#  ('Lead',
#   'Typhoid fever'): ([Page('Lead'),
#    Page('Centers for Disease Control and Prevention'),
#    Page('Typhoid fever')], 2),
#  ('Fashion',
#   'Bette Midler'): ([Page('Fashion'),
#    Page('Hazmat suit'),
#    Page('Fire hose'),
#    Page('Ozone'),
#    Page('Propene'),
#    Page('Bentazepam'),
#    Page('Anthramycin'),
#    Page('DNA'),
#    Page('Robert W. Holley'),
#    Page('Eric F. Wieschaus'),
#    Page('Maternal effect'),
#    Page('Diabetes mellitus type 2'),
#    Page('EMedicine'),
#    Page('National Cancer Institute'),
#    Page('NIH Record'),
#    Page('United States government'),
#    Page('Federal government of the United States'),
#    Page('Midwestern United States'),
#    Page('Lawrence University'),
#    Page('Bruce Iglauer'),
#    Page('Delmark Records'),
#    Page('For Alto'),
#    Page('Creative Orchestra (Köln) 1978'),
#    Page('Thurman Barker'),
#    Page('Bette Midler')], 37),
#  ('Death',
#   'Apple Lisa'): ([Page('Death'),
#    Page('Digital object identifier'),
#    Page('Cut, copy, and paste'),
#    Page('Apple Lisa')], 8),
#  ('Electron',
#   'Bosnia and Herzegovina'): ([Page('Electron'),
#    Page('De Magnete'),
#    Page('Magnetic dip'),
#    Page('South Magnetic Pole'),
#    Page('Iceland'),
#    Page('Bosnia and Herzegovina')], 7),
#  ('String theory',
#   'Gastroesophageal reflux disease'): ([Page('String theory'),
#    Page('Arvind Rajaraman'),
#    Page('University of California, Irvine'),
#    Page('University of California, Irvine School of Social Sciences'),
#    Page('Economics'),
#    Page('The Problem of Social Cost'),
#    Page('Deed'),
#    Page('Doctrine of lapse'),
#    Page('Tulsipur State'),
#    Page('Tribhuvannagar'),
#    Page('Ghorahi'),
#    Page('Dharan, Nepal'),
#    Page('Bhedetar'),
#    Page('Postal code'),
#    Page('Aberystwyth'),
#    Page('Walter Payton'),
#    Page('Primary sclerosing cholangitis'),
#    Page('Gastroesophageal reflux disease')], 31),
#  ('Nuclear Power',
#   'Breakfast'): ([Page('Nuclear Power'),
#    Page('Nuclear power'),
#    Page('Food'),
#    Page('Breakfast')], 3),
#  ('Aryan',
#   'Magnetic resonance imaging'): ([Page('Aryan'),
#    Page('Dynasty'),
#    Page('20th century'),
#    Page('Magnetic resonance imaging')], 3),
#  ('Persecution of Christians',
#   'Wall Street'): ([Page('Persecution of Christians'),
#    Page('World War I'),
#    Page('Wall Street')], 2),
#  ('Tomato',
#   'Stock market'): ([Page('Tomato'), Page('Egypt'), Page('Stock market')], 2),
#  ('Nuclear warfare',
#   'DNA replication'): ([Page('Nuclear warfare'),
#    Page('Advanced gas-cooled reactor'),
#    Page('Advanced Gas-cooled Reactor'),
#    Page('UK Power Networks'),
#    Page('Docklands Light Railway'),
#    Page('Quality Line'),
#    Page('Corporate spin-off'),
#    Page('Australia'),
#    Page('Thylacine'),
#    Page('Genetics'),
#    Page('DNA replication')],
#   19),
#  ('Dimension',
#   'Memory'): ([Page('Dimension'),
#    Page('Experimental psychology'),
#    Page('Memory')], 2),
#  ('Periodic table',
#   'Gastroesophageal reflux disease'): ([Page('Periodic table'),
#    Page('Selenium'),
#    Page('Enprostil'),
#    Page('Gastroesophageal reflux disease')], 4),
#  ('Southern California',
#   'Diazepam'): ([Page('Southern California'),
#    Page('South Los Angeles'),
#    Page('Jay Rock'),
#    Page('2013 Bet Hip Hop Awards'),
#    Page('Acid Rap'),
#    Page('BJ the Chicago Kid'),
#    Page('Crystal Aikin'),
#    Page('41st GMA Dove Awards'),
#    Page('BEC Recordings'),
#    Page('Tooth & Nail Records discography'),
#    Page('Warlord (hardcore band)'),
#    Page('Fibromyalgia'),
#    Page('Carbamazepine'),
#    Page('Diazepam')], 28),
#  ('Charles Bronson',
#   'Architecture'): ([Page('Charles Bronson'),
#    Page('Architect'),
#    Page('Architecture')], 2),
#  ('Romanticism',
#   'Sigmund Freud'): ([Page('Romanticism'),
#    Page('Zygmunt Bauman'),
#    Page('Sigmund Freud')], 2),
#  ('Internal combustion engine',
#   'Ballet'): ([Page('Internal combustion engine'),
#    Page('Piston ring'),
#    Page('Carburetor heat'),
#    Page('Light aircraft'),
#    Page('Trijet'),
#    Page('Yakovlev Yak-42'),
#    Page('Maximum takeoff weight'),
#    Page('Munich air disaster'),
#    Page('A.C. Milan'),
#    Page('Robert Doornbos'),
#    Page('Red Bull RB8'),
#    Page('Red Bulls'),
#    Page('2016 Summer European League of Legends Championship Series'),
#    Page('Kraków'),
#    Page('Linz'),
#    Page('Ballet')], 29),
#  ('J. R. R. Tolkien',
#   'Luciano Pavarotti'): ([Page('J. R. R. Tolkien'),
#    Page('Edgbaston'),
#    Page('Saltley'),
#    Page('Adderley Park'),
#    Page('RSPB Sandwell Valley'),
#    Page('Sandwell Valley RSPB reserve'),
#    Page('Eurasian teal'),
#    Page('Hunting and shooting in the United Kingdom'),
#    Page('Fox hunting'),
#    Page('Sting (musician)'),
#    Page('Luciano Pavarotti')], 17),
#  ('Ecosystem',
#   'Four Tops'): ([Page('Ecosystem'),
#    Page('Ecological goods and services'),
#    Page('Ecolabel'),
#    Page('Environmental history'),
#    Page('Attitude (psychology)'),
#    Page('Bibliothèque nationale de France'),
#    Page('Musée Jacquemart-André'),
#    Page('Madeleine (Paris Métro)'),
#    Page('Aimé Césaire (Paris Métro)'),
#    Page('Seine-Saint-Denis'),
#    Page('Stade Vélodrome'),
#    Page('2014–15 Ligue 1'),
#    Page('2014–15 Olympique Lyonnais season'),
#    Page('Gabriel Enache'),
#    Page('2018–19 FK Partizan season'),
#    Page('2018–19 UEFA Europa League qualifying phase and play-off round'),
#    Page('Lithuanian Football Cup'),
#    Page('Elnias Šiauliai'),
#    Page('1960–61 LFF Lyga'),
#    Page('1981 LFF Lyga'),
#    Page('1980–81 Bundesliga'),
#    Page('2002–03 Bundesliga'),
#    Page('2002–03 UEFA Champions League qualifying rounds'),
#    Page('Gregor Pötscher'),
#    Page('Heinz Binder'),
#    Page('Branko Elsner'),
#    Page('Karl Stotz'),
#    Page('Frank Schinkels'),
#    Page('Dancing Stars (Austria season 10)'),
#    Page('Four Tops')], 44),
#  ('Frank Gehry',
#   'Will Smith'): ([Page('Frank Gehry'),
#    Page('Robert Redford'),
#    Page('Will Smith')], 2),
#  ('Feces',
#   'Entertainment'): ([Page('Feces'),
#    Page('Disgust'),
#    Page('Entertainment')], 2),
#  ('Louis Armstrong',
#   'Airline'): ([Page('Louis Armstrong'),
#    Page('Moon River'),
#    Page('Billboard 200'),
#    Page('Airline')], 3),
#  ('Constantinople',
#   'Montreal'): ([Page('Constantinople'),
#    Page('Romanization of Greek'),
#    Page('Montreal')], 2),
#  ('Pulmonary embolism',
#   'Periodic table'): ([Page('Pulmonary embolism'),
#    Page('Technetium'),
#    Page('Periodic table')], 2),
#  ('Onomatopoeia',
#   'Apple Lisa'): ([Page('Onomatopoeia'),
#    Page('Jay'),
#    Page('Yellow-billed blue magpie'),
#    Page('Least Concern'),
#    Page('Least-concern species'),
#    Page('Extinction'),
#    Page('Administration (probate law)'),
#    Page('Administration'),
#    Page('Administrator'),
#    Page('Server administrator'),
#    Page('Server Admin (application)'),
#    Page('Spotlight (software)'),
#    Page('Core OpenGL'),
#    Page('Apple Inc. design motifs'),
#    Page('IMac G5'),
#    Page('Apple Lisa')], 26),
#  ('Birdman (rapper)',
#   'Taxonomy (biology)'): ([Page('Birdman (rapper)'),
#    Page('Rich Homie Quan'),
#    Page('Louisville, Georgia'),
#    Page('Municipal corporation'),
#    Page('Corporation of Chennai'),
#    Page('Greater Chennai Corporation'),
#    Page('Paramakudi'),
#    Page('Borassus flabellifer'),
#    Page('Taxonomy (biology)')], 15),
#  ('Lacrosse',
#   'Satire'): ([Page('Lacrosse'),
#    Page('Lacrosse glove'),
#    Page('Goalkeeper glove'),
#    Page('Kit (association football)'),
#    Page('Penalty kick (association football)'),
#    Page('Jimmy McIlroy'),
#    Page('Cliff Bastin'),
#    Page('WorldCat'),
#    Page('Interlibrary loan'),
#    Page('Standardization'),
#    Page('Economics'),
#    Page('Satire')], 19),
#  ('Chemical reaction',
#   'Matter'): ([Page('Chemical reaction'),
#    Page('Mass balance'),
#    Page('Matter')], 2),
#  ('Continental Army',
#   'Organization'): ([Page('Continental Army'),
#    Page('Treaty of Paris (1783)'),
#    Page('Midnight Judges Act'),
#    Page('United States federal judicial district'),
#    Page('Montgomery, Alabama'),
#    Page('Muscle Shoals, Alabama'),
#    Page('Marriage'),
#    Page('Organization')], 11),
#  ('Americans',
#   'West Indies'): ([Page('Americans'),
#    Page('Bermuda'),
#    Page('West Indies')], 2),
#  ('Carrie Fisher',
#   'Ant'): ([Page('Carrie Fisher'), Page('Harrison Ford'), Page('Ant')], 2),
#  ('Climate',
#   'Atmosphere of Earth'): ([Page('Climate'), Page('Atmosphere of Earth')], 1),
#  ('Train',
#   'Envy'): ([Page('Train'),
#    Page('Intermodal container'),
#    Page('3M-54 Klub'),
#    Page('3M-54 Kalibr'),
#    Page('R-40 (missile)'),
#    Page('Klimov RD-500'),
#    Page('Turboprop'),
#    Page('Federal Aviation Administration'),
#    Page('Thomas C. Richards'),
#    Page('United Nations Korea Medal'),
#    Page('Spanish language'),
#    Page('Marshall Islands'),
#    Page('South Dakota'),
#    Page('Harrisburg, South Dakota'),
#    Page('Sioux City, Iowa'),
#    Page('A League of Their Own'),
#    Page('Ann Cusack'),
#    Page('Malice (film)'),
#    Page('A Few Good Men'),
#    Page('A Few Good Men (disambiguation)'),
#    Page('A Few Good Men (The Vampire Diaries)'),
#    Page('Blood Brothers (The Vampire Diaries)'),
#    Page('Blood brother (disambiguation)'),
#    Page('Human Again'),
#    Page('Human Again (song)'),
#    Page('Gaston (Beauty and the Beast)'),
#    Page('Egotism'),
#    Page('Envy')],
#   40),
#  ('Early Middle Ages',
#   'Ku Klux Klan'): ([Page('Early Middle Ages'),
#    Page('Chivalry'),
#    Page('Ku Klux Klan')], 2),
#  ('Augustus',
#   'Magnetic field'): ([Page('Augustus'),
#    Page('Religion in ancient Rome'),
#    Page('Climate of ancient Rome'),
#    Page('Polis'),
#    Page('Planet'),
#    Page('Magnetic field')], 7),
#  ('Parthenon',
#   'United Nations Charter'): ([Page('Parthenon'),
#    Page('Theotokos'),
#    Page('Ecumenism'),
#    Page('Calvinism'),
#    Page('United Nations Charter')], 7),
#  ('Metaphysics',
#   'Technology'): ([Page('Metaphysics'),
#    Page('Glossary of philosophy'),
#    Page('Technology')], 2),
#  ('Polynesia',
#   'Queens of the Stone Age'): ([Page('Polynesia'),
#    Page('Gulf of Aqaba'),
#    Page('Tourism in Jordan'),
#    Page('Shark tourism'),
#    Page('Do not feed the animals'),
#    Page('Bird feeder'),
#    Page('Plastic'),
#    Page('Dioctyl adipate'),
#    Page('Institute for Occupational Safety and Health'),
#    Page('Institute for Occupational Safety and Health of the German Social Accident Insurance'),
#    Page('Information technology'),
#    Page('Information processing'),
#    Page('Connectionism'),
#    Page('Philosophy of mind'),
#    Page('David Hume'),
#    Page('Mahatma Gandhi'),
#    Page('Asian of the Century'),
#    Page('Canadian Newsmaker of the Year (Time)'),
#    Page('1995 in Canada'),
#    Page('2013 in Canada'),
#    Page('2013 in Canadian music'),
#    Page('2013 in Irish music'),
#    Page('2010 in Irish music'),
#    Page('2010 in Australian music'),
#    Page('2012 in Australian music'),
#    Page('2012 in Asian music'),
#    Page('2018 in Asian music'),
#    Page('2018 in heavy metal music'),
#    Page('2016 in heavy metal music'),
#    Page('Seven Kingdoms (band)'),
#    Page('Aghora (band)'),
#    Page('Æon Spoke'),
#    Page('Paul Masvidal'),
#    Page('Queens of the Stone Age')], 38),
#  ('Computer Multitasking', 'Broadway theatre'): (False, 3),
#  ('Celsius',
#   'Wiki'): ([Page('Celsius'),
#    Page('Encyclopædia Britannica'),
#    Page('Wiki')], 2),
#  ('Mick Jagger',
#   'Personal digital assistant'): ([Page('Mick Jagger'),
#    Page('MSN'),
#    Page('Personal digital assistant')], 2),
#  ('Ashley Massaro',
#   'Embedded system'): ([Page('Ashley Massaro'),
#    Page('Survivor: Nicaragua'),
#    Page('San Juan del Sur'),
#    Page('Nicaragua Canal'),
#    Page('Politics of Nicaragua'),
#    Page('Politics of Costa Rica'),
#    Page('Wildlife of Costa Rica'),
#    Page('Stingless bee'),
#    Page('Honey bee'),
#    Page('Bee sting'),
#    Page('Manganism'),
#    Page('Glutamate'),
#    Page('Phrase'),
#    Page('Diminutive'),
#    Page('Code name'),
#    Page('90 nanometer'),
#    Page('MCST-R1000'),
#    Page('MCST-R500S'),
#    Page('MBus (SPARC)'),
#    Page('Arbiter (electronics)'),
#    Page('Metastability (electronics)'),
#    Page('Mead & Conway revolution'),
#    Page('VLSI Project'),
#    Page('DragonFly BSD'),
#    Page('Comparison of operating system kernels'),
#    Page('Unix security'),
#    Page('Loopback'),
#    Page('Internet protocol suite'),
#    Page('Embedded system')], 30)}
